# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing as StandardScaler
from sklearn.impute import KNNImputer
import seaborn as sns
from scipy.stats import zscore
from sklearn.model_selection import train_test_split
from category_encoders import BinaryEncoder


#import tensorflow as tf
#import tensorflow.keras as keras

# %% [markdown]
# # Introduction

# %% [markdown]
# - [Reading Data](#Reading_Data)
# - [Understanding Data](#Understanding_Data)
# - [Compare Done And Canceled Requests In Features](#comparing_done_and_canceled_requests_in_features)

# %% [markdown]
# # Reading Data

# %%
df = pd.read_csv('HW2_train.csv')
df.head(10)
# Out:
#    distance  price  buying_equipment  intercity                   datetime  \
# 0     12832   1320                 0          0  2012-11-17 19:46:44+03:30
# 1      7230   1560                 0          0  2012-11-19 16:32:03+03:30
# 2      6974   1700                 0          0  2012-11-14 12:59:43+03:30
# 3      5535   1260                 0          0  2012-11-15 18:03:49+03:30
# 4      3229    700                 0          0  2012-11-15 22:06:07+03:30
# 5      4578   1060                 0          0  2012-11-19 09:24:52+03:30
# 6     14606   1760                 0          0  2012-11-18 15:17:33+03:30
# 7      9377   2560                 0          0  2012-11-13 16:12:21+03:30
# 8      6134   1620                 0          0  2012-11-21 16:55:24+03:30
# 9      2819    660                 0          0  2012-11-21 16:34:08+03:30
#
#   service_type  days_since_signup  in_hurry_enabled  done expert_group
# 0            A               1699                 0     0          NaN
# 1            A                336                 0     1            A
# 2            A                 14                 0     1            A
# 3            A                653                 0     1            A
# 4            A                739                 0     1            A
# 5            A                 44                 1     0            A
# 6            A                435                 1     1            A
# 7            A               1003                 0     0            A
# 8            A                  9                 0     0            A
# 9            A                121                 0     0          NaN

# %% [markdown]
# # Understanding Data

# %% [markdown]
# ## Done:

# %%
unique_values = sorted(df['done'].unique())
bins = np.arange(min(unique_values) - 0.5, max(unique_values) + 1, 1)

plt.figure(figsize=(5, 5))
plt.hist(df['done'], bins=bins, color='blue', rwidth=0.4, alpha=0.6)

plt.xticks(unique_values)
plt.xlabel('done')
plt.ylabel('Count')
plt.title('Frequency of done Values')
plt.show()

# %% [markdown]
# ## Distance:

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['distance'], bins=50, color='blue', alpha=0.6)

plt.xlabel('Distance')
plt.ylabel('Count')
plt.title('Distribution of Distance Values')
plt.show()

# %%
days_df = df[df['distance'] < 0]['distance'].value_counts().reset_index(name='count')
days_df.columns = ['distance', 'count']
len(days_df)
# Out:
# 0

# %% [markdown]
# ## Price:

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['price'], bins=60, color='blue', alpha=0.6)

plt.xlabel('Price')
plt.ylabel('Count')
plt.title('Distribution of Price Values')
plt.show()

# %%
days_df = df[df['price'] < 0]['price'].value_counts().reset_index(name='count')
days_df.columns = ['price', 'count']
len(days_df)
# Out:
# 0

# %% [markdown]
# ## Buying Equipment:

# %%
unique_values = sorted(df['buying_equipment'].unique())
bins = np.arange(min(unique_values) - 0.5, max(unique_values) + 1, 1)

plt.figure(figsize=(5, 5))
plt.hist(df['buying_equipment'], bins=bins, color='blue', rwidth=0.4, alpha=0.6)

plt.xticks(unique_values)
plt.xlabel('Buying Equipment')
plt.ylabel('Count')
plt.title('Frequency of Buying Equipment Values')
plt.show()

# %%
eq_df = df['buying_equipment'].value_counts().reset_index(name='count')
eq_df.columns = ['buying_equipment', 'count']
eq_df
# Out:
#    buying_equipment  count
# 0                 0  75689
# 1                 1    968

# %% [markdown]
# ## Intercity:

# %%
unique_values = sorted(df['intercity'].unique())
bins = np.arange(min(unique_values) - 0.5, max(unique_values) + 1, 1)

plt.figure(figsize=(5, 5))
plt.hist(df['intercity'], bins=bins, color='blue', rwidth=0.4, alpha=0.6)

plt.xticks(unique_values)
plt.xlabel('Intercity')
plt.ylabel('Count')
plt.title('Frequency of Intercity Values')
plt.show()

# %%
intercity_df = df['intercity'].value_counts().reset_index(name='count')
intercity_df.columns = ['intercity', 'count']
intercity_df
# Out:
#    intercity  count
# 0          0  76605
# 1          1     52

# %% [markdown]
# ## Service Type:

# %%
unique_values = sorted(df['service_type'].unique())

bins = np.arange(len(unique_values) + 1) - 0.5

service_type_numeric = df['service_type'].astype('category').cat.codes

plt.figure(figsize=(5, 5))
plt.hist(service_type_numeric, bins=bins, color='blue', rwidth=0.4, alpha=0.6)

plt.xticks(range(len(unique_values)), unique_values)

plt.xlabel('Service Type')
plt.ylabel('Count')
plt.title('Frequency of Service Type Values')
plt.show()

# %%
service_df = df['service_type'].value_counts().reset_index(name='count')
service_df.columns = ['service_type', 'count']
service_df
# Out:
#   service_type  count
# 0            A  76293
# 1            E    140
# 2            B    113
# 3            D     67
# 4            C     44

# %% [markdown]
# ## In Hurry:

# %%
unique_values = sorted(df['in_hurry_enabled'].unique())
bins = np.arange(min(unique_values) - 0.5, max(unique_values) + 1, 1)

plt.figure(figsize=(5, 5))
plt.hist(df['in_hurry_enabled'], bins=bins, color='blue', rwidth=0.4, alpha=0.6)

plt.xticks(unique_values)
plt.xlabel('In Hurry Enabled')
plt.ylabel('Count')
plt.title('Frequency of In Hurry Enabled Values')
plt.show()

# %%
hurry_df = df['in_hurry_enabled'].value_counts().reset_index(name='count')
hurry_df.columns = ['in_hurry_enabled', 'count']
hurry_df
# Out:
#    in_hurry_enabled  count
# 0                 0  69107
# 1                 1   7423
# 2                 2    120
# 3                 3      7

# %% [markdown]
# ## Days Since Signup:

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['days_since_signup'], bins=30, color='red', alpha=0.5)

plt.xlabel('Days Since Signup')
plt.ylabel('Count')
plt.title('Distribution of Days Since Signup')
plt.show()

# %%
days_df = df[df['days_since_signup'] < 0]['days_since_signup'].value_counts().reset_index(name='count')
days_df.columns = ['days_since_signup', 'count']
days_df
# Out:
#    days_since_signup  count
# 0                 -1    334

# %% [markdown]
# ## Expert Group:

# %%
df['expert_group'] = df['expert_group'].fillna('Unknown').astype(str)

unique_values = sorted(df['expert_group'].unique())

bins = np.arange(len(unique_values) + 1) - 0.5

expert_group_numeric = df['expert_group'].astype('category').cat.codes

plt.figure(figsize=(5, 5))
plt.hist(expert_group_numeric, bins=bins, color='blue', rwidth=0.4, alpha=0.6)

plt.xticks(range(len(unique_values)), unique_values, rotation=45)

plt.xlabel('Expert Group')
plt.ylabel('Count')
plt.title('Frequency of Expert Group Values')
plt.show()

# %%
exp_df = df['expert_group'].value_counts().reset_index(name='count')
exp_df.columns = ['expert_group', 'count']
exp_df
# Out:
#   expert_group  count
# 0            A  66882
# 1      Unknown   9026
# 2            B    749

# %% [markdown]
# # Comparing Done And Canceled Requests In Features:

# %%
#features = ['distance', 'price', 'days_since_signup', 'datetime'] 
features = ['distance', 'price', 'days_since_signup'] 

plt.figure(figsize=(12, len(features) * 4))

for i, feature in enumerate(features, 1):
    plt.subplot(len(features), 1, i)
    sns.kdeplot(data=df[df['done'] == 1], x=feature, fill=True, label='done = 1', color="blue", alpha=0.5)
    sns.kdeplot(data=df[df['done'] == 0], x=feature, fill=True, label='done = 0', color="red", alpha=0.5)
    plt.title(f'Density Plot of {feature}')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# List of features with discrete values
discrete_features = ['buying_equipment', 'service_type', 'intercity']  # Replace with your actual feature names

plt.figure(figsize=(12, len(discrete_features) * 4))

for i, feature in enumerate(discrete_features, 1):
    plt.subplot(len(discrete_features), 1, i)
    sns.histplot(data=df[df['done'] == 1], x=feature, color="blue", alpha=0.5, label='done = 1', stat='count', bins=10)
    sns.histplot(data=df[df['done'] == 0], x=feature, color="red", alpha=0.5, label='done = 0', stat='count', bins=10)
    plt.title(f'Histogram of {feature}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Relations Between Feature

# %% [markdown]
# ## Price And Distance:

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data=df, x='distance', y='price', hue='done', 
                palette={1: 'blue', 0: 'red'}, s=50, alpha=0.4)

plt.title('Scatter plot of Price vs Distance')
plt.xlabel('Distance')
plt.ylabel('Price')
plt.legend(title='Done', labels=['Not Done (0)', 'Done (1)'])

plt.show()

# %% [markdown]
# #### These two features are correlated.

# %% [markdown]
# ## Price And Sign Up Days:

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data=df, x='days_since_signup', y='price', hue='done', 
                palette={1: 'blue', 0: 'red'}, s=50, alpha=0.2)

plt.title('Scatter plot of Price vs Signup Days')
plt.xlabel('Signup Days')
plt.ylabel('Price')

plt.show()

# %% [markdown]
# ## Price And Datetime:

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data=df, x='datetime', y='price', hue='done', 
                palette={1: 'blue', 0: 'red'}, s=50, alpha=0.2)

plt.title('Scatter plot of Price vs Signup Days')
plt.xlabel('Signup Days')
plt.ylabel('Price')
plt.xticks(rotation = 45)
plt.legend(title='Done', labels=['Not Done (0)', 'Done (1)'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 3
#       1 plt.figure(figsize=(10, 6))
# ----> 3 sns.scatterplot(data=df, x='datetime', y='price', hue='done',
#       4                 palette={1: 'blue', 0: 'red'}, s=50, alpha=0.2)
#       6 plt.title('Scatter plot of Price vs Signup Days')
#       7 plt.xlabel('Signup Days')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\relational.py:461, in _ScatterPlotter.plot(self, ax, kws)
#     458     kws["linewidth"] = linewidth
#     460 # Finalize the axes details
# --> 461 self._add_axis_labels(ax)
#     462 if self.legend:
#     463     attrs = {"hue": "color", "size": "s", "style": None}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:1196, in VectorPlotter._add_axis_labels(self, ax, default_x, default_y)
#    1191 # TODO ax could default to None and use attached axes if present
#    1192 # but what to do about the case of facets? Currently using FacetGrid's
#    1193 # set_axis_labels method, which doesn't add labels to the interior even
#    1194 # when the axes are not shared. Maybe that makes sense?
#    1195 if not ax.get_xlabel():
# -> 1196     x_visible = any(t.get_visible() for t in ax.get_xticklabels())
#    1197     ax.set_xlabel(self.variables.get("x", default_x), visible=x_visible)
#    1198 if not ax.get_ylabel():
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1502, in Axis.get_ticklabels(self, minor, which)
#    1500 if minor:
#    1501     return self.get_minorticklabels()
# -> 1502 return self.get_majorticklabels()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1459, in Axis.get_majorticklabels(self)
#    1457 def get_majorticklabels(self):
#    1458     """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1459     self._update_ticks()
#    1460     ticks = self.get_major_ticks()
#    1461     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1301, in Axis._update_ticks(self)
#    1299 major_locs = self.get_majorticklocs()
#    1300 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1301 major_ticks = self.get_major_ticks(len(major_locs))
#    1302 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#    1303     tick.update_position(loc)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1661, in Axis.get_major_ticks(self, numticks)
#    1657     numticks = len(self.get_majorticklocs())
#    1659 while len(self.majorTicks) < numticks:
#    1660     # Update the new tick label properties from the old.
# -> 1661     tick = self._get_tick(major=True)
#    1662     self.majorTicks.append(tick)
#    1663     self._copy_tick_props(self.majorTicks[0], tick)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1597, in Axis._get_tick(self, major)
#    1593     raise NotImplementedError(
#    1594         f"The Axis subclass {self.__class__.__name__} must define "
#    1595         "_tick_class or reimplement _get_tick()")
#    1596 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1597 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:398, in XTick.__init__(self, *args, **kwargs)
#     397 def __init__(self, *args, **kwargs):
# --> 398     super().__init__(*args, **kwargs)
#     399     # x in data coords, y in axes coords
#     400     ax = self.axes
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:170, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, labelfontfamily, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     160 self.tick1line = mlines.Line2D(
#     161     [], [],
#     162     color=color, linestyle="none", zorder=zorder, visible=tick1On,
#     163     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     164 )
#     165 self.tick2line = mlines.Line2D(
#     166     [], [],
#     167     color=color, linestyle="none", zorder=zorder, visible=tick2On,
#     168     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     169 )
# --> 170 self.gridline = mlines.Line2D(
#     171     [], [],
#     172     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     173     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     174     **grid_kw,
#     175 )
#     176 self.gridline.get_path()._interpolation_steps = \
#     177     GRIDLINE_INTERPOLATION_STEPS
#     178 self.label1 = mtext.Text(
#     179     np.nan, np.nan,
#     180     fontsize=labelsize, color=labelcolor, visible=label1On,
#     181     fontfamily=labelfontfamily, rotation=self._labelrotation[1])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\lines.py:362, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     360 self.set_dash_capstyle(dash_capstyle)
#     361 self.set_dash_joinstyle(dash_joinstyle)
# --> 362 self.set_solid_capstyle(solid_capstyle)
#     363 self.set_solid_joinstyle(solid_joinstyle)
#     365 self._linestyles = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\lines.py:1435, in Line2D.set_solid_capstyle(self, s)
#    1424 @_docstring.interpd
#    1425 def set_solid_capstyle(self, s):
#    1426     """
#    1427     How to draw the end caps if the line is solid (not `~Line2D.is_dashed`)
#    1428
#    (...)
#    1433     s : `.CapStyle` or %(CapStyle)s
#    1434     """
# -> 1435     cs = CapStyle(s)
#    1436     if self._solidcapstyle != cs:
#    1437         self.stale = True
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\enum.py:726, in EnumType.__call__(cls, value, names, module, qualname, type, start, boundary, *values)
#     721     """
#     722     classes/types should always be True.
#     723     """
#     724     return True
# --> 726 def __call__(cls, value, names=_not_given, *values, module=None, qualname=None, type=None, start=1, boundary=None):
#     727     """
#     728     Either returns an existing member, or creates a new enum class.
#     729
#    (...)
#     751     `type`, if set, will be mixed in as the first base class.
#     752     """
#     753     if cls._member_map_:
#     754         # simple value lookup if members exist
#
# KeyboardInterrupt:

# %% [markdown]
# # Checking Duplicated Rows

# %%
num_duplicates = df.duplicated().sum()
print(f"Number of duplicated rows: {num_duplicates}")
# Out:
# Number of duplicated rows: 0

# %% [markdown]
# # Null Values

# %%
missingValues = df.isnull().sum()
missingValues
# Out:
# distance             0
# price                0
# buying_equipment     0
# intercity            0
# datetime             0
# service_type         0
# days_since_signup    0
# in_hurry_enabled     0
# done                 0
# expert_group         0
# dtype: int64

# %% [markdown]
# #### Only The Expert Group Consists Null Values.

# %% [markdown]
# # Separating Train Set

# %%
train_df, valid_df = train_test_split(df, test_size=0.15, random_state=42, stratify=df['done'])

# %% [markdown]
# # Outlier Detection On Train Set
# ## (Should Be Checked After Training)

# %% [markdown]
# ## Distance:

# %%
sns.boxplot(x=train_df['distance'], color = '#4340ff')
plt.show()

# %%
column = 'distance'

Q1 = train_df[column].quantile(0.25)
Q3 = train_df[column].quantile(0.75)
IQR = Q3 - Q1

upper_bound = Q3 + 1.2 * IQR

outliers = train_df[(train_df[column] > upper_bound)]
inliers = train_df[(train_df[column] <= upper_bound)]

print(f"Number of outliers: {len(outliers)}")
print(f"Number of inliers: {len(inliers)}")

df_cleaned = inliers

# %%
sns.boxplot(x=df_cleaned['distance'], color = '#4340ff')
plt.show()

# %% [markdown]
# ## Price:

# %%
sns.boxplot(x=df_cleaned['price'], color = '#4340ff')
plt.show()

# %%
column = 'price'

Q1 = df_cleaned[column].quantile(0.25)
Q3 = df_cleaned[column].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.4 * IQR

outliers = df_cleaned[(df_cleaned[column] > upper_bound) | (df_cleaned[column] < lower_bound)]
inliers = df_cleaned[(df_cleaned[column] <= upper_bound) & (df_cleaned[column] >= lower_bound)]

print(f"Number of outliers: {len(outliers)}")
print(f"Number of inliers: {len(inliers)}")

df_cleaned1 = inliers

# %%
sns.boxplot(x=df_cleaned1['price'], color = '#4340ff')
plt.show()

# %% [markdown]
# ## Days Since Signup:

# %%
len(df_cleaned1[df_cleaned1['days_since_signup'] < 0])

# %%
df_cleaned1 = df_cleaned1.drop(df_cleaned1[df_cleaned1['days_since_signup'] < 0].index)

# %%
features = ['distance', 'price']  # Replace with your actual feature names

# Set up the plotting grid
plt.figure(figsize=(12, len(features) * 4))

for i, feature in enumerate(features, 1):
    plt.subplot(len(features), 1, i)
    sns.kdeplot(data=df_cleaned1[df_cleaned1['done'] == 1], x=feature, fill=True, label='done = 1', color="blue", alpha=0.5)
    sns.kdeplot(data=df_cleaned1[df_cleaned1['done'] == 0], x=feature, fill=True, label='done = 0', color="red", alpha=0.5)
    plt.title(f'Density Plot of {feature}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Dealing With Null Values For Expert Group

# %% [markdown]
# ## Converting Categorical Values Using Binary Encoding

# %%
encoder = BinaryEncoder(cols=['service_type'])
encoded_df = encoder.fit_transform(df_cleaned1)

# %%
encoded_df

# %% [markdown]
# # --- SHOULD BE CHECKED

# %%
fill_df = df[["in_hurry_enabled", "service_type", "expert_group"]]
non_null_df = fill_df[fill_df["expert_group"].notna()]
null_df = fill_df[fill_df["expert_group"].isna()]

x_non_null = non_null_df.drop(columns = ["expert_group"])
y_non_null = non_null_df["expert_group"].astype("category").cat.codes

categories = non_null_df["expert_group"].astype("category").cat.categories

x_null = null_df.drop(columns = ["expert_group"])

y_non_null = y_non_null.astype("category").cat.categories

imputer = KNNImputer(n_neighbors = 2)
imputer.fit(x_non_null)

x_null_imputed = imputer.transform(x_null)

null_df = null_df.copy()

null_df["expert_group"] = pd.Categorical.from_codes(
    x_null_imputed[:, -1].round().astype(int), categories
)

#null_df.loc[:, "expert_group"] = x_null_imputed[:, -1]

final_df = pd.concat([non_null_df, null_df])

final_df
