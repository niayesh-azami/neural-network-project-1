# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing as StandardScaler
from sklearn.impute import KNNImputer
import seaborn as sns
from scipy.stats import zscore
from sklearn.model_selection import train_test_split
from category_encoders import BinaryEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.metrics import Precision
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
import tensorflow.keras as keras

# %% [markdown]
# # Introduction

# %% [markdown]
# - [Reading Data](#Reading_Data)
# - [Understanding Data](#Understanding_Data)
# - [Compare Done And Canceled Requests In Features](#comparing_done_and_canceled_requests_in_features)

# %% [markdown]
# # Reading Data

# %%
df = pd.read_csv('HW2_train.csv')
df.head(10)
# Out:
#    distance  price  buying_equipment  intercity                   datetime  \
# 0     12832   1320                 0          0  2012-11-17 19:46:44+03:30
# 1      7230   1560                 0          0  2012-11-19 16:32:03+03:30
# 2      6974   1700                 0          0  2012-11-14 12:59:43+03:30
# 3      5535   1260                 0          0  2012-11-15 18:03:49+03:30
# 4      3229    700                 0          0  2012-11-15 22:06:07+03:30
# 5      4578   1060                 0          0  2012-11-19 09:24:52+03:30
# 6     14606   1760                 0          0  2012-11-18 15:17:33+03:30
# 7      9377   2560                 0          0  2012-11-13 16:12:21+03:30
# 8      6134   1620                 0          0  2012-11-21 16:55:24+03:30
# 9      2819    660                 0          0  2012-11-21 16:34:08+03:30
#
#   service_type  days_since_signup  in_hurry_enabled  done expert_group
# 0            A               1699                 0     0          NaN
# 1            A                336                 0     1            A
# 2            A                 14                 0     1            A
# 3            A                653                 0     1            A
# 4            A                739                 0     1            A
# 5            A                 44                 1     0            A
# 6            A                435                 1     1            A
# 7            A               1003                 0     0            A
# 8            A                  9                 0     0            A
# 9            A                121                 0     0          NaN

# %% [markdown]
# # Understanding Data

# %% [markdown]
# ## Done:

# %%
unique_values = sorted(df['done'].unique())
bins = np.arange(min(unique_values) - 0.5, max(unique_values) + 1, 1)

plt.figure(figsize=(5, 5))
plt.hist(df['done'], bins=bins, color='blue', rwidth=0.4, alpha=0.6)

plt.xticks(unique_values)
plt.xlabel('done')
plt.ylabel('Count')
plt.title('Frequency of done Values')
plt.show()

# %% [markdown]
# ## Distance:

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['distance'], bins=50, color='blue', alpha=0.6)

plt.xlabel('Distance')
plt.ylabel('Count')
plt.title('Distribution of Distance Values')
plt.show()

# %%
days_df = df[df['distance'] < 0]['distance'].value_counts().reset_index(name='count')
days_df.columns = ['distance', 'count']
len(days_df)
# Out:
# 0

# %% [markdown]
# ## Price:

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['price'], bins=60, color='blue', alpha=0.6)

plt.xlabel('Price')
plt.ylabel('Count')
plt.title('Distribution of Price Values')
plt.show()

# %%
days_df = df[df['price'] < 0]['price'].value_counts().reset_index(name='count')
days_df.columns = ['price', 'count']
len(days_df)
# Out:
# 0

# %% [markdown]
# ## Buying Equipment:

# %%
unique_values = sorted(df['buying_equipment'].unique())
bins = np.arange(min(unique_values) - 0.5, max(unique_values) + 1, 1)

plt.figure(figsize=(5, 5))
plt.hist(df['buying_equipment'], bins=bins, color='blue', rwidth=0.4, alpha=0.6)

plt.xticks(unique_values)
plt.xlabel('Buying Equipment')
plt.ylabel('Count')
plt.title('Frequency of Buying Equipment Values')
plt.show()

# %%
eq_df = df['buying_equipment'].value_counts().reset_index(name='count')
eq_df.columns = ['buying_equipment', 'count']
eq_df
# Out:
#    buying_equipment  count
# 0                 0  75689
# 1                 1    968

# %% [markdown]
# ## Intercity:

# %%
unique_values = sorted(df['intercity'].unique())
bins = np.arange(min(unique_values) - 0.5, max(unique_values) + 1, 1)

plt.figure(figsize=(5, 5))
plt.hist(df['intercity'], bins=bins, color='blue', rwidth=0.4, alpha=0.6)

plt.xticks(unique_values)
plt.xlabel('Intercity')
plt.ylabel('Count')
plt.title('Frequency of Intercity Values')
plt.show()

# %%
intercity_df = df['intercity'].value_counts().reset_index(name='count')
intercity_df.columns = ['intercity', 'count']
intercity_df
# Out:
#    intercity  count
# 0          0  76605
# 1          1     52

# %% [markdown]
# ## Service Type:

# %%
unique_values = sorted(df['service_type'].unique())

bins = np.arange(len(unique_values) + 1) - 0.5

service_type_numeric = df['service_type'].astype('category').cat.codes

plt.figure(figsize=(5, 5))
plt.hist(service_type_numeric, bins=bins, color='blue', rwidth=0.4, alpha=0.6)

plt.xticks(range(len(unique_values)), unique_values)

plt.xlabel('Service Type')
plt.ylabel('Count')
plt.title('Frequency of Service Type Values')
plt.show()

# %%
service_df = df['service_type'].value_counts().reset_index(name='count')
service_df.columns = ['service_type', 'count']
service_df
# Out:
#   service_type  count
# 0            A  76293
# 1            E    140
# 2            B    113
# 3            D     67
# 4            C     44

# %% [markdown]
# ## In Hurry:

# %%
unique_values = sorted(df['in_hurry_enabled'].unique())
bins = np.arange(min(unique_values) - 0.5, max(unique_values) + 1, 1)

plt.figure(figsize=(5, 5))
plt.hist(df['in_hurry_enabled'], bins=bins, color='blue', rwidth=0.4, alpha=0.6)

plt.xticks(unique_values)
plt.xlabel('In Hurry Enabled')
plt.ylabel('Count')
plt.title('Frequency of In Hurry Enabled Values')
plt.show()

# %%
hurry_df = df['in_hurry_enabled'].value_counts().reset_index(name='count')
hurry_df.columns = ['in_hurry_enabled', 'count']
hurry_df
# Out:
#    in_hurry_enabled  count
# 0                 0  69107
# 1                 1   7423
# 2                 2    120
# 3                 3      7

# %% [markdown]
# ## Days Since Signup:

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['days_since_signup'], bins=30, color='red', alpha=0.5)

plt.xlabel('Days Since Signup')
plt.ylabel('Count')
plt.title('Distribution of Days Since Signup')
plt.show()

# %%
days_df = df[df['days_since_signup'] < 0]['days_since_signup'].value_counts().reset_index(name='count')
days_df.columns = ['days_since_signup', 'count']
days_df
# Out:
#    days_since_signup  count
# 0                 -1    334

# %% [markdown]
# ## Expert Group:

# %%
df['expert_group'] = df['expert_group'].fillna('Unknown').astype(str)

unique_values = sorted(df['expert_group'].unique())

bins = np.arange(len(unique_values) + 1) - 0.5

expert_group_numeric = df['expert_group'].astype('category').cat.codes

plt.figure(figsize=(5, 5))
plt.hist(expert_group_numeric, bins=bins, color='blue', rwidth=0.4, alpha=0.6)

plt.xticks(range(len(unique_values)), unique_values, rotation=45)

plt.xlabel('Expert Group')
plt.ylabel('Count')
plt.title('Frequency of Expert Group Values')
plt.show()

# %%
exp_df = df['expert_group'].value_counts().reset_index(name='count')
exp_df.columns = ['expert_group', 'count']
exp_df
# Out:
#   expert_group  count
# 0            A  66882
# 1      Unknown   9026
# 2            B    749

# %% [markdown]
# # Comparing Done And Canceled Requests In Features:

# %%
#features = ['distance', 'price', 'days_since_signup', 'datetime'] 
features = ['distance', 'price', 'days_since_signup'] 

plt.figure(figsize=(12, len(features) * 4))

for i, feature in enumerate(features, 1):
    plt.subplot(len(features), 1, i)
    sns.kdeplot(data=df[df['done'] == 1], x=feature, fill=True, label='done = 1', color="blue", alpha=0.5)
    sns.kdeplot(data=df[df['done'] == 0], x=feature, fill=True, label='done = 0', color="red", alpha=0.5)
    plt.title(f'Density Plot of {feature}')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
df
# Out:
#        distance  price  buying_equipment  intercity  \
# 0         12832   1320                 0          0
# 1          7230   1560                 0          0
# 2          6974   1700                 0          0
# 3          5535   1260                 0          0
# 4          3229    700                 0          0
# ...         ...    ...               ...        ...
# 76652      6199   1560                 0          0
# 76653      8667   2040                 0          0
# 76654      1003    620                 0          0
# 76655      1995    960                 0          0
# 76656      3847    700                 0          0
#
#                         datetime service_type  days_since_signup  \
# 0      2012-11-17 19:46:44+03:30            A               1699
# 1      2012-11-19 16:32:03+03:30            A                336
# 2      2012-11-14 12:59:43+03:30            A                 14
# 3      2012-11-15 18:03:49+03:30            A                653
# 4      2012-11-15 22:06:07+03:30            A                739
# ...                          ...          ...                ...
# 76652  2012-11-19 12:14:17+03:30            A                104
# 76653  2012-11-20 20:52:53+03:30            A               1311
# 76654  2012-11-13 15:37:52+03:30            A                847
# 76655  2012-11-18 18:04:58+03:30            A                401
# 76656  2012-11-17 09:27:39+03:30            A                 69
#
#        in_hurry_enabled  done expert_group
# 0                     0     0      Unknown
# 1                     0     1            A
# 2                     0     1            A
# 3                     0     1            A
# 4                     0     1            A
# ...                 ...   ...          ...
# 76652                 0     1            A
# 76653                 0     0            A
# 76654                 0     1            A
# 76655                 1     1            A
# 76656                 0     1            A
#
# [76657 rows x 10 columns]

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['time'] = df['datetime'].dt.strftime('%H:%M:%S')
df['time'] = pd.to_timedelta(df['time']).dt.total_seconds()
df['time'] = df['time']/3600
df
# Out:
#        distance  price  buying_equipment  intercity                  datetime  \
# 0         12832   1320                 0          0 2012-11-17 19:46:44+03:30
# 1          7230   1560                 0          0 2012-11-19 16:32:03+03:30
# 2          6974   1700                 0          0 2012-11-14 12:59:43+03:30
# 3          5535   1260                 0          0 2012-11-15 18:03:49+03:30
# 4          3229    700                 0          0 2012-11-15 22:06:07+03:30
# ...         ...    ...               ...        ...                       ...
# 76652      6199   1560                 0          0 2012-11-19 12:14:17+03:30
# 76653      8667   2040                 0          0 2012-11-20 20:52:53+03:30
# 76654      1003    620                 0          0 2012-11-13 15:37:52+03:30
# 76655      1995    960                 0          0 2012-11-18 18:04:58+03:30
# 76656      3847    700                 0          0 2012-11-17 09:27:39+03:30
#
#       service_type  days_since_signup  in_hurry_enabled  done expert_group  \
# 0                A               1699                 0     0      Unknown
# 1                A                336                 0     1            A
# 2                A                 14                 0     1            A
# 3                A                653                 0     1            A
# 4                A                739                 0     1            A
# ...            ...                ...               ...   ...          ...
# 76652            A                104                 0     1            A
# 76653            A               1311                 0     0            A
# 76654            A                847                 0     1            A
# 76655            A                401                 1     1            A
# 76656            A                 69                 0     1            A
#
#             time
# 0      19.778889
# 1      16.534167
# 2      12.995278
# 3      18.063611
# 4      22.101944
# ...          ...
# 76652  12.238056
# 76653  20.881389
# 76654  15.631111
# 76655  18.082778
# 76656   9.460833
#
# [76657 rows x 11 columns]

# %%
'''plt.subplot(len('time'), 1, i)
sns.kdeplot(data=df[df['done'] == 1], x='time', fill=True, label='done = 1', color="blue", alpha=0.5)
sns.kdeplot(data=df[df['done'] == 0], x='time', fill=True, label='done = 0', color="red", alpha=0.5)
plt.title(f'Density Plot of time')
plt.legend()

plt.tight_layout()
plt.show()''

plt.figure(figsize=(10, 6))
sns.kdeplot(data=df[df['done'] == 1], x='time', fill=True, label='done = 1', color="blue", alpha=0.5)
sns.kdeplot(data=df[df['done'] == 0], x='time', fill=True, label='done = 0', color="red", alpha=0.5)
plt.title('Density Plot of Time')
plt.legend()
plt.tight_layout()
plt.show()
'''


plt.figure(figsize=(10, 6))
sns.kdeplot(data=df[df['done'] == 1], x='time', fill=True, label='done = 1', color="blue", alpha=0.5)
sns.kdeplot(data=df[df['done'] == 0], x='time', fill=True, label='done = 0', color="red", alpha=0.5)
plt.title('Density Plot of Time')
plt.legend()
plt.tight_layout()
plt.show()

# %%
discrete_features = ['buying_equipment', 'service_type', 'intercity']  

plt.figure(figsize=(12, len(discrete_features) * 4))

for i, feature in enumerate(discrete_features, 1):
    plt.subplot(len(discrete_features), 1, i)
    sns.histplot(data=df[df['done'] == 1], x=feature, color="blue", alpha=0.5, label='done = 1', stat='count', bins=10)
    sns.histplot(data=df[df['done'] == 0], x=feature, color="red", alpha=0.5, label='done = 0', stat='count', bins=10)
    plt.title(f'Histogram of {feature}')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Relations Between Feature

# %% [markdown]
# ## Price And Distance:

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data=df, x='distance', y='price', hue='done', 
                palette={1: 'blue', 0: 'red'}, s=50, alpha=0.4)

plt.title('Scatter plot of Price vs Distance')
plt.xlabel('Distance')
plt.ylabel('Price')
plt.legend(title='Done', labels=['Not Done (0)', 'Done (1)'])

plt.show()

# %% [markdown]
# #### These two features are correlated.

# %% [markdown]
# ## Price And Sign Up Days:

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data=df, x='days_since_signup', y='price', hue='done', 
                palette={1: 'blue', 0: 'red'}, s=50, alpha=0.2)

plt.title('Scatter plot of Price vs Signup Days')
plt.xlabel('Signup Days')
plt.ylabel('Price')

plt.show()

# %% [markdown]
# ## Price And Datetime:

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data=df.sample(frac=0.2), x='datetime', y='price', hue='done', 
                palette={1: 'blue', 0: 'red'}, s = 50, alpha=0.2)

plt.title('Scatter plot of Price vs Signup Days')
plt.ylabel('Price')
#plt.xticks(rotation = 45)
plt.legend(title='Done', labels=['Not Done (0)', 'Done (1)'])
plt.xticks([])

plt.show()
print("****")
# Out:
# ****

# %% [markdown]
# # Checking Duplicated Rows

# %%
num_duplicates = df.duplicated().sum()
print(f"Number of duplicated rows: {num_duplicates}")
# Out:
# Number of duplicated rows: 0

# %% [markdown]
# # Null Values

# %%
missingValues = df.isnull().sum()
missingValues
# Out:
# distance             0
# price                0
# buying_equipment     0
# intercity            0
# datetime             0
# service_type         0
# days_since_signup    0
# in_hurry_enabled     0
# done                 0
# expert_group         0
# time                 0
# dtype: int64

# %% [markdown]
# #### Only The Expert Group Consists Null Values.

# %% [markdown]
# # Separating Train Set

# %%
train_df, valid_df = train_test_split(df, test_size=0.15, random_state=42, stratify=df['done'])

# %% [markdown]
# # Outlier Detection On Train Set
# ## (Should Be Checked After Training)

# %% [markdown]
# ## Distance:

# %%
sns.boxplot(x=train_df['distance'], color = '#4340ff')
plt.show()

# %%
column = 'distance'

Q1 = train_df[column].quantile(0.25)
Q3 = train_df[column].quantile(0.75)
IQR = Q3 - Q1

upper_bound = Q3 + 1.2 * IQR

outliers = train_df[(train_df[column] > upper_bound)]
inliers = train_df[(train_df[column] <= upper_bound)]

print(f"Number of outliers: {len(outliers)}")
print(f"Number of inliers: {len(inliers)}")

df_cleaned = inliers
# Out:
# Number of outliers: 4107
# Number of inliers: 61051

# %%
sns.boxplot(x=df_cleaned['distance'], color = '#4340ff')
plt.show()

# %% [markdown]
# ## Price:

# %%
sns.boxplot(x=df_cleaned['price'], color = '#4340ff')
plt.show()

# %%
column = 'price'

Q1 = df_cleaned[column].quantile(0.25)
Q3 = df_cleaned[column].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.4 * IQR

outliers = df_cleaned[(df_cleaned[column] > upper_bound) | (df_cleaned[column] < lower_bound)]
inliers = df_cleaned[(df_cleaned[column] <= upper_bound) & (df_cleaned[column] >= lower_bound)]

print(f"Number of outliers: {len(outliers)}")
print(f"Number of inliers: {len(inliers)}")

df_cleaned1 = inliers
# Out:
# Number of outliers: 1409
# Number of inliers: 59642

# %%
sns.boxplot(x=df_cleaned1['price'], color = '#4340ff')
plt.show()

# %% [markdown]
# ## Days Since Signup:

# %%
len(df_cleaned1[df_cleaned1['days_since_signup'] < 0])
# Out:
# 238

# %%
df_cleaned1 = df_cleaned1.drop(df_cleaned1[df_cleaned1['days_since_signup'] < 0].index)

# %%
features = ['distance', 'price']  # Replace with your actual feature names

# Set up the plotting grid
plt.figure(figsize=(12, len(features) * 4))

for i, feature in enumerate(features, 1):
    plt.subplot(len(features), 1, i)
    sns.kdeplot(data=df_cleaned1[df_cleaned1['done'] == 1], x=feature, fill=True, label='done = 1', color="blue", alpha=0.5)
    sns.kdeplot(data=df_cleaned1[df_cleaned1['done'] == 0], x=feature, fill=True, label='done = 0', color="red", alpha=0.5)
    plt.title(f'Density Plot of {feature}')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
train_df = df_cleaned1

# %% [markdown]
# # Normalization

# %%
scaler = MinMaxScaler()
train_df['distance'] = scaler.fit_transform(train_df[['distance']])

train_df['price'] = scaler.fit_transform(train_df[['price']])

train_df['days_since_signup'] = scaler.fit_transform(train_df[['days_since_signup']])

# %%
train_df
# Out:
#        distance     price  buying_equipment  intercity  \
# 65119  0.346311  0.462366                 0          0
# 30768  0.533066  1.000000                 1          0
# 50138  0.426362  0.473118                 0          0
# 38661  0.315019  0.483871                 0          0
# 73623  0.246248  0.559140                 0          0
# ...         ...       ...               ...        ...
# 55048  0.871646  0.752688                 0          0
# 43165  0.531884  0.720430                 0          0
# 17250  0.385609  0.430108                 0          0
# 65026  0.496771  0.451613                 0          0
# 57680  0.326299  0.473118                 0          0
#
#                        datetime service_type  days_since_signup  \
# 65119 2012-11-21 18:22:47+03:30            A           0.210526
# 30768 2012-11-20 17:31:31+03:30            A           0.683413
# 50138 2012-11-18 13:43:01+03:30            A           0.159888
# 38661 2012-11-18 18:22:15+03:30            A           0.123206
# 73623 2012-11-18 12:18:09+03:30            A           0.165470
# ...                         ...          ...                ...
# 55048 2012-11-13 18:22:09+03:30            A           0.803429
# 43165 2012-11-17 17:17:57+03:30            A           0.234848
# 17250 2012-11-12 22:05:24+03:30            A           0.092903
# 65026 2012-11-20 10:28:03+03:30            A           0.301834
# 57680 2012-11-19 11:49:35+03:30            A           0.537081
#
#        in_hurry_enabled  done expert_group       time
# 65119                 0     1            A  18.379722
# 30768                 1     0            A  17.525278
# 50138                 0     0            A  13.716944
# 38661                 0     1            A  18.370833
# 73623                 1     1            A  12.302500
# ...                 ...   ...          ...        ...
# 55048                 0     0      Unknown  18.369167
# 43165                 1     1            A  17.299167
# 17250                 0     1            A  22.090000
# 65026                 0     1            B  10.467500
# 57680                 0     1            A  11.826389
#
# [59404 rows x 11 columns]

# %% [markdown]
# # Dealing With Null Values For Expert Group

# %% [markdown]
# ## Converting Categorical Values Using Binary Encoding

# %%
len(train_df[train_df['expert_group']=='B'])
# Out:
# 617

# %%
len(train_df[train_df['expert_group'].isna()])
# Out:
# 0

# %%
train_df.replace('Unknown', np.nan, inplace=True)

# %%
encoder = BinaryEncoder(cols=['service_type'])
encoded_df = encoder.fit_transform(train_df)

# %%
encoded_df
# Out:
#        distance     price  buying_equipment  intercity  \
# 65119  0.346311  0.462366                 0          0
# 30768  0.533066  1.000000                 1          0
# 50138  0.426362  0.473118                 0          0
# 38661  0.315019  0.483871                 0          0
# 73623  0.246248  0.559140                 0          0
# ...         ...       ...               ...        ...
# 55048  0.871646  0.752688                 0          0
# 43165  0.531884  0.720430                 0          0
# 17250  0.385609  0.430108                 0          0
# 65026  0.496771  0.451613                 0          0
# 57680  0.326299  0.473118                 0          0
#
#                        datetime  service_type_0  service_type_1  \
# 65119 2012-11-21 18:22:47+03:30               0               0
# 30768 2012-11-20 17:31:31+03:30               0               0
# 50138 2012-11-18 13:43:01+03:30               0               0
# 38661 2012-11-18 18:22:15+03:30               0               0
# 73623 2012-11-18 12:18:09+03:30               0               0
# ...                         ...             ...             ...
# 55048 2012-11-13 18:22:09+03:30               0               0
# 43165 2012-11-17 17:17:57+03:30               0               0
# 17250 2012-11-12 22:05:24+03:30               0               0
# 65026 2012-11-20 10:28:03+03:30               0               0
# 57680 2012-11-19 11:49:35+03:30               0               0
#
#        service_type_2  days_since_signup  in_hurry_enabled  done expert_group  \
# 65119               1           0.210526                 0     1            A
# 30768               1           0.683413                 1     0            A
# 50138               1           0.159888                 0     0            A
# 38661               1           0.123206                 0     1            A
# 73623               1           0.165470                 1     1            A
# ...               ...                ...               ...   ...          ...
# 55048               1           0.803429                 0     0          NaN
# 43165               1           0.234848                 1     1            A
# 17250               1           0.092903                 0     1            A
# 65026               1           0.301834                 0     1            B
# 57680               1           0.537081                 0     1            A
#
#             time
# 65119  18.379722
# 30768  17.525278
# 50138  13.716944
# 38661  18.370833
# 73623  12.302500
# ...          ...
# 55048  18.369167
# 43165  17.299167
# 17250  22.090000
# 65026  10.467500
# 57680  11.826389
#
# [59404 rows x 13 columns]

# %%
fill_df = encoded_df[["distance", "price", "buying_equipment", "in_hurry_enabled", "service_type_0", "service_type_1", "service_type_2", "time", "expert_group"]]
non_null_df = fill_df[fill_df["expert_group"].notna()]
null_df = fill_df[fill_df["expert_group"].isna()]

x_non_null = non_null_df.drop(columns=["expert_group"])
y_non_null = non_null_df["expert_group"].astype("category").cat.codes

categories = non_null_df["expert_group"].astype("category").cat.categories

x_null = null_df.drop(columns=["expert_group"])

imputer = KNNImputer(n_neighbors=2)
imputer.fit(x_non_null)

x_null_imputed = imputer.transform(x_null)

null_df = null_df.copy() 

codes = np.clip(x_null_imputed[:, -1].round().astype(int), 0, len(categories) - 1)

null_df = null_df.copy() 

null_df.loc[:, "expert_group"] = pd.Categorical.from_codes(codes, categories=categories)

final_df = pd.concat([non_null_df, null_df])

final_df

null_df = null_df.copy()

# %%
len(final_df[final_df['expert_group']=='B'])
# Out:
# 5218

# %%
final_df["expert_group"] = final_df["expert_group"].map({"A": 1, "B": 0})

# %%
final_df
# Out:
#        distance     price  buying_equipment  in_hurry_enabled  service_type_0  \
# 65119  0.346311  0.462366                 0                 0               0
# 30768  0.533066  1.000000                 1                 1               0
# 50138  0.426362  0.473118                 0                 0               0
# 38661  0.315019  0.483871                 0                 0               0
# 73623  0.246248  0.559140                 0                 1               0
# ...         ...       ...               ...               ...             ...
# 13692  0.716638  0.279570                 0                 0               0
# 73018  0.793323  0.612903                 0                 0               0
# 36295  0.615665  0.526882                 0                 0               0
# 53875  0.524970  0.236559                 0                 0               0
# 55048  0.871646  0.752688                 0                 0               0
#
#        service_type_1  service_type_2       time  expert_group
# 65119               0               1  18.379722             1
# 30768               0               1  17.525278             1
# 50138               0               1  13.716944             1
# 38661               0               1  18.370833             1
# 73623               0               1  12.302500             1
# ...               ...             ...        ...           ...
# 13692               0               1  16.962500             0
# 73018               0               1  14.492500             0
# 36295               0               1  12.563889             0
# 53875               0               1   7.611111             0
# 55048               0               1  18.369167             0
#
# [59404 rows x 9 columns]

# %%
df_train = train_df
df_train.drop(columns="service_type", inplace=True)
df_train.drop(columns="expert_group", inplace=True)

# %%
df_train = df_train.merge(final_df, left_index = True, right_index = True)

# %%
df_train
# Out:
#        distance_x   price_x  buying_equipment_x  intercity  \
# 65119    0.346311  0.462366                   0          0
# 30768    0.533066  1.000000                   1          0
# 50138    0.426362  0.473118                   0          0
# 38661    0.315019  0.483871                   0          0
# 73623    0.246248  0.559140                   0          0
# ...           ...       ...                 ...        ...
# 55048    0.871646  0.752688                   0          0
# 43165    0.531884  0.720430                   0          0
# 17250    0.385609  0.430108                   0          0
# 65026    0.496771  0.451613                   0          0
# 57680    0.326299  0.473118                   0          0
#
#                        datetime  days_since_signup  in_hurry_enabled_x  done  \
# 65119 2012-11-21 18:22:47+03:30           0.210526                   0     1
# 30768 2012-11-20 17:31:31+03:30           0.683413                   1     0
# 50138 2012-11-18 13:43:01+03:30           0.159888                   0     0
# 38661 2012-11-18 18:22:15+03:30           0.123206                   0     1
# 73623 2012-11-18 12:18:09+03:30           0.165470                   1     1
# ...                         ...                ...                 ...   ...
# 55048 2012-11-13 18:22:09+03:30           0.803429                   0     0
# 43165 2012-11-17 17:17:57+03:30           0.234848                   1     1
# 17250 2012-11-12 22:05:24+03:30           0.092903                   0     1
# 65026 2012-11-20 10:28:03+03:30           0.301834                   0     1
# 57680 2012-11-19 11:49:35+03:30           0.537081                   0     1
#
#           time_x  distance_y   price_y  buying_equipment_y  \
# 65119  18.379722    0.346311  0.462366                   0
# 30768  17.525278    0.533066  1.000000                   1
# 50138  13.716944    0.426362  0.473118                   0
# 38661  18.370833    0.315019  0.483871                   0
# 73623  12.302500    0.246248  0.559140                   0
# ...          ...         ...       ...                 ...
# 55048  18.369167    0.871646  0.752688                   0
# 43165  17.299167    0.531884  0.720430                   0
# 17250  22.090000    0.385609  0.430108                   0
# 65026  10.467500    0.496771  0.451613                   0
# 57680  11.826389    0.326299  0.473118                   0
#
#        in_hurry_enabled_y  service_type_0  service_type_1  service_type_2  \
# 65119                   0               0               0               1
# 30768                   1               0               0               1
# 50138                   0               0               0               1
# 38661                   0               0               0               1
# 73623                   1               0               0               1
# ...                   ...             ...             ...             ...
# 55048                   0               0               0               1
# 43165                   1               0               0               1
# 17250                   0               0               0               1
# 65026                   0               0               0               1
# 57680                   0               0               0               1
#
#           time_y  expert_group
# 65119  18.379722             1
# 30768  17.525278             1
# 50138  13.716944             1
# 38661  18.370833             1
# 73623  12.302500             1
# ...          ...           ...
# 55048  18.369167             0
# 43165  17.299167             1
# 17250  22.090000             1
# 65026  10.467500             0
# 57680  11.826389             1
#
# [59404 rows x 18 columns]

# %%
df_train = df_train.rename(columns={"distance_x": "distance", "price_x": "price", "buying_equipment_x": "buying_equipment"})
df_train = df_train.rename(columns={"in_hurry_enabled_x": "in_hurry_enabled", "time_x": "time"})
df_train.drop(columns=["distance_y", "price_y", "buying_equipment_y", "in_hurry_enabled_y", "time_y"], inplace=True)

# %%
train_df = df_train
train_df
# Out:
#        distance     price  buying_equipment  intercity  \
# 65119  0.346311  0.462366                 0          0
# 30768  0.533066  1.000000                 1          0
# 50138  0.426362  0.473118                 0          0
# 38661  0.315019  0.483871                 0          0
# 73623  0.246248  0.559140                 0          0
# ...         ...       ...               ...        ...
# 55048  0.871646  0.752688                 0          0
# 43165  0.531884  0.720430                 0          0
# 17250  0.385609  0.430108                 0          0
# 65026  0.496771  0.451613                 0          0
# 57680  0.326299  0.473118                 0          0
#
#                        datetime  days_since_signup  in_hurry_enabled  done  \
# 65119 2012-11-21 18:22:47+03:30           0.210526                 0     1
# 30768 2012-11-20 17:31:31+03:30           0.683413                 1     0
# 50138 2012-11-18 13:43:01+03:30           0.159888                 0     0
# 38661 2012-11-18 18:22:15+03:30           0.123206                 0     1
# 73623 2012-11-18 12:18:09+03:30           0.165470                 1     1
# ...                         ...                ...               ...   ...
# 55048 2012-11-13 18:22:09+03:30           0.803429                 0     0
# 43165 2012-11-17 17:17:57+03:30           0.234848                 1     1
# 17250 2012-11-12 22:05:24+03:30           0.092903                 0     1
# 65026 2012-11-20 10:28:03+03:30           0.301834                 0     1
# 57680 2012-11-19 11:49:35+03:30           0.537081                 0     1
#
#             time  service_type_0  service_type_1  service_type_2  expert_group
# 65119  18.379722               0               0               1             1
# 30768  17.525278               0               0               1             1
# 50138  13.716944               0               0               1             1
# 38661  18.370833               0               0               1             1
# 73623  12.302500               0               0               1             1
# ...          ...             ...             ...             ...           ...
# 55048  18.369167               0               0               1             0
# 43165  17.299167               0               0               1             1
# 17250  22.090000               0               0               1             1
# 65026  10.467500               0               0               1             0
# 57680  11.826389               0               0               1             1
#
# [59404 rows x 13 columns]

# %%
train_df.drop('datetime', axis=1, inplace=True)

# %%
train_df
# Out:
#        distance     price  buying_equipment  intercity  days_since_signup  \
# 65119  0.346311  0.462366                 0          0           0.210526
# 30768  0.533066  1.000000                 1          0           0.683413
# 50138  0.426362  0.473118                 0          0           0.159888
# 38661  0.315019  0.483871                 0          0           0.123206
# 73623  0.246248  0.559140                 0          0           0.165470
# ...         ...       ...               ...        ...                ...
# 55048  0.871646  0.752688                 0          0           0.803429
# 43165  0.531884  0.720430                 0          0           0.234848
# 17250  0.385609  0.430108                 0          0           0.092903
# 65026  0.496771  0.451613                 0          0           0.301834
# 57680  0.326299  0.473118                 0          0           0.537081
#
#        in_hurry_enabled  done       time  service_type_0  service_type_1  \
# 65119                 0     1  18.379722               0               0
# 30768                 1     0  17.525278               0               0
# 50138                 0     0  13.716944               0               0
# 38661                 0     1  18.370833               0               0
# 73623                 1     1  12.302500               0               0
# ...                 ...   ...        ...             ...             ...
# 55048                 0     0  18.369167               0               0
# 43165                 1     1  17.299167               0               0
# 17250                 0     1  22.090000               0               0
# 65026                 0     1  10.467500               0               0
# 57680                 0     1  11.826389               0               0
#
#        service_type_2  expert_group
# 65119               1             1
# 30768               1             1
# 50138               1             1
# 38661               1             1
# 73623               1             1
# ...               ...           ...
# 55048               1             0
# 43165               1             1
# 17250               1             1
# 65026               1             0
# 57680               1             1
#
# [59404 rows x 12 columns]

# %% [markdown]
# # Preparing Validation Set

# %%
valid_df.drop('datetime', axis=1, inplace=True)
valid_df
# Out:
#        distance  price  buying_equipment  intercity service_type  \
# 17649      4520    920                 0          0            A
# 61383      6582   1520                 0          0            A
# 38410      3288   1060                 0          0            A
# 6854       5179    920                 0          0            A
# 55829      3731   1520                 1          0            A
# ...         ...    ...               ...        ...          ...
# 34143      4855   1220                 0          0            A
# 39542      3500   1220                 0          0            A
# 17136      8114   1900                 0          0            A
# 34232      4676   1540                 0          0            A
# 64724      3618   1360                 0          0            A
#
#        days_since_signup  in_hurry_enabled  done expert_group       time
# 17649                 33                 0     1            A  23.603056
# 61383                424                 1     1            A   0.000000
# 38410               1440                 0     1            A  15.237778
# 6854                   6                 1     0      Unknown  11.839167
# 55829                517                 0     1            A  13.548889
# ...                  ...               ...   ...          ...        ...
# 34143                170                 0     1            A  13.205000
# 39542                438                 0     0            A  21.938889
# 17136               1137                 1     0            A  19.723056
# 34232                489                 1     0            A  15.893889
# 64724               1405                 0     1            A  19.101111
#
# [11499 rows x 10 columns]

# %%
encoder = BinaryEncoder(cols=['service_type'])
encoded_df = encoder.fit_transform(valid_df)

# %%
encoded_df
# Out:
#        distance  price  buying_equipment  intercity  service_type_0  \
# 17649      4520    920                 0          0               0
# 61383      6582   1520                 0          0               0
# 38410      3288   1060                 0          0               0
# 6854       5179    920                 0          0               0
# 55829      3731   1520                 1          0               0
# ...         ...    ...               ...        ...             ...
# 34143      4855   1220                 0          0               0
# 39542      3500   1220                 0          0               0
# 17136      8114   1900                 0          0               0
# 34232      4676   1540                 0          0               0
# 64724      3618   1360                 0          0               0
#
#        service_type_1  service_type_2  days_since_signup  in_hurry_enabled  \
# 17649               0               1                 33                 0
# 61383               0               1                424                 1
# 38410               0               1               1440                 0
# 6854                0               1                  6                 1
# 55829               0               1                517                 0
# ...               ...             ...                ...               ...
# 34143               0               1                170                 0
# 39542               0               1                438                 0
# 17136               0               1               1137                 1
# 34232               0               1                489                 1
# 64724               0               1               1405                 0
#
#        done expert_group       time
# 17649     1            A  23.603056
# 61383     1            A   0.000000
# 38410     1            A  15.237778
# 6854      0      Unknown  11.839167
# 55829     1            A  13.548889
# ...     ...          ...        ...
# 34143     1            A  13.205000
# 39542     0            A  21.938889
# 17136     0            A  19.723056
# 34232     0            A  15.893889
# 64724     1            A  19.101111
#
# [11499 rows x 12 columns]

# %%
valid_df = encoded_df
caler = MinMaxScaler()
valid_df['distance'] = scaler.fit_transform(valid_df[['distance']])

valid_df['price'] = scaler.fit_transform(valid_df[['price']])

valid_df['days_since_signup'] = scaler.fit_transform(valid_df[['days_since_signup']])

# %%
valid_backup = valid_df

# %%
valid_df["expert_group"] = valid_df["expert_group"].map({"A": 1, "B": 0, "Unknown": -1})

# %%
valid_df
# Out:
#        distance     price  buying_equipment  intercity  service_type_0  \
# 17649  0.005672  0.011194                 0          0               0
# 61383  0.008259  0.020522                 0          0               0
# 38410  0.004126  0.013371                 0          0               0
# 6854   0.006499  0.011194                 0          0               0
# 55829  0.004682  0.020522                 1          0               0
# ...         ...       ...               ...        ...             ...
# 34143  0.006092  0.015858                 0          0               0
# 39542  0.004392  0.015858                 0          0               0
# 17136  0.010182  0.026430                 0          0               0
# 34232  0.005868  0.020833                 0          0               0
# 64724  0.004540  0.018035                 0          0               0
#
#        service_type_1  service_type_2  days_since_signup  in_hurry_enabled  \
# 17649               0               1           0.013266                 0
# 61383               0               1           0.165821                 1
# 38410               0               1           0.562232                 0
# 6854                0               1           0.002731                 1
# 55829               0               1           0.202107                 0
# ...               ...             ...                ...               ...
# 34143               0               1           0.066719                 0
# 39542               0               1           0.171284                 0
# 17136               0               1           0.444011                 1
# 34232               0               1           0.191182                 1
# 64724               0               1           0.548576                 0
#
#        done  expert_group       time
# 17649     1             1  23.603056
# 61383     1             1   0.000000
# 38410     1             1  15.237778
# 6854      0            -1  11.839167
# 55829     1             1  13.548889
# ...     ...           ...        ...
# 34143     1             1  13.205000
# 39542     0             1  21.938889
# 17136     0             1  19.723056
# 34232     0             1  15.893889
# 64724     1             1  19.101111
#
# [11499 rows x 12 columns]

# %%
train_df
# Out:
#        distance     price  buying_equipment  intercity  days_since_signup  \
# 65119  0.346311  0.462366                 0          0           0.210526
# 30768  0.533066  1.000000                 1          0           0.683413
# 50138  0.426362  0.473118                 0          0           0.159888
# 38661  0.315019  0.483871                 0          0           0.123206
# 73623  0.246248  0.559140                 0          0           0.165470
# ...         ...       ...               ...        ...                ...
# 55048  0.871646  0.752688                 0          0           0.803429
# 43165  0.531884  0.720430                 0          0           0.234848
# 17250  0.385609  0.430108                 0          0           0.092903
# 65026  0.496771  0.451613                 0          0           0.301834
# 57680  0.326299  0.473118                 0          0           0.537081
#
#        in_hurry_enabled  done       time  service_type_0  service_type_1  \
# 65119                 0     1  18.379722               0               0
# 30768                 1     0  17.525278               0               0
# 50138                 0     0  13.716944               0               0
# 38661                 0     1  18.370833               0               0
# 73623                 1     1  12.302500               0               0
# ...                 ...   ...        ...             ...             ...
# 55048                 0     0  18.369167               0               0
# 43165                 1     1  17.299167               0               0
# 17250                 0     1  22.090000               0               0
# 65026                 0     1  10.467500               0               0
# 57680                 0     1  11.826389               0               0
#
#        service_type_2  expert_group
# 65119               1             1
# 30768               1             1
# 50138               1             1
# 38661               1             1
# 73623               1             1
# ...               ...           ...
# 55048               1             0
# 43165               1             1
# 17250               1             1
# 65026               1             0
# 57680               1             1
#
# [59404 rows x 12 columns]

# %% [markdown]
# # Building Model

# %%
#x_train = train_df.drop('done', axis=1)
#x_valid = valid_df.drop('done', axis=1)

x_train = train_df[['price', 'distance']]
x_valid = valid_df[['price', 'distance']]

#x_train = x_train.drop('distance', axis=1)
#x_valid = x_valid.drop('distance', axis=1)

#############
#x_train = train_df.drop(columns=['distance', 'days_since_signup', 'service_type_0', 'service_type_1', 'service_type_2'])
#x_valid = valid_df.drop(columns=['distance', 'days_since_signup', 'service_type_0', 'service_type_1', 'service_type_2'])
#x_train = train_df.drop(columns=['days_since_signup', 'done', 'time'])
#x_valid = valid_df.drop(columns=['days_since_signup', 'done', 'time'])

#############

#x_train = x_train.drop('expert_group', axis=1)
#x_valid = x_valid.drop('expert_group', axis=1)

y_train = train_df['done']
y_valid = valid_df['done']

# %%
input_shape = [x_train.shape[1]]
input_shape
# Out:
# [2]

# %% [markdown]
# ## Loss Weight

# %%
class_labels = np.unique(y_train)
class_weight = compute_class_weight(class_weight='balanced', classes=class_labels, y=y_train)
class_weight = dict(enumerate(class_weight))

# %%
print(class_weights)
# Out:
# {0: np.float64(1.974079489565333), 1: np.float64(0.6695973668785788)}

# %%
unique_classes = np.unique(y_train)
print("unique: ", unique_classes)
print("class with weight keys: ", class_weights.keys())
# Out:
# unique:  [0 1]
# class with weight keys:  dict_keys([0, 1])

# %%
'''model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    tf.keras.layers.Dense(units=16, activation='relu'),
    tf.keras.layers.Dense(units=16, activation='relu'),
    #tf.keras.layers.Dense(units=16, activation='relu'),
    #tf.keras.layers.Dense(units=64, activation='sigmoid'),
    tf.keras.layers.Dense(units=1)
])
model.summary()'''
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='sigmoid')  # Use sigmoid for binary classification
])
model.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_36 (Dense)                     │ (None, 128)                 │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_37 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_38 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_39 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,753 (42.00 KB)
#  Trainable params: 10,753 (42.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
'''#model.compile(optimizer='adam', loss='mae')  
model.compile(optimizer='adam', 
              loss='binary_crossentropy',  # Or another loss function depending on your task
              metrics=['accuracy', Precision()])
'''

def specificity(y_true, y_pred):
    tn = tf.reduce_sum(tf.cast((y_true == 0) & (tf.round(y_pred) == 0), tf.float32))
    fp = tf.reduce_sum(tf.cast((y_true == 0) & (tf.round(y_pred) == 1), tf.float32))
    specificity = tn / (tn + fp + tf.keras.backend.epsilon())
    return specificity

model.compile(optimizer='adam', 
              loss='binary_crossentropy',
              #metrics=['accuracy', Precision()])
              metrics=['accuracy', 'recall'])

# %%
'''history_with_weights = model.fit(x_train, y_train, validation_data = (x_valid, y_valid), 
    batch_size=32,
    epochs=100, 
    class_weight = {0: 1.0, 1: 2.0},)'''

'''
history_with_weights = model.fit(
    X_train_scaled, y_train, epochs=100, class_weight=class_weights, validation_data=(X_test_scaled, y_test), batch_size=32)
'''
# Out:
# '\nhistory_with_weights = model.fit(\n    X_train_scaled, y_train, epochs=100, class_weight=class_weights, validation_data=(X_test_scaled, y_test), batch_size=32)\n'

# %%
class_weight = {0: 2.0,
                1: 1.0}

# %%
losses = model.fit(x_train, y_train,
    validation_data=(x_valid, y_valid),
    batch_size=256, 
    epochs=10,  
    #class_weight=class_weight
    )

'''# Evaluate the model with class weights
loss_with_weights, accuracy_with_weights = model.evaluate(x_valid, y_valid)
print(f"Test Loss with class weights: {loss_with_weights}")
print(f"Test Accuracy with class weights: {accuracy_with_weights}")'''
# Out:
# Epoch 1/10
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7723 - loss: 0.5232 - recall: 0.9847 - val_accuracy: 0.2899 - val_loss: 2.9502 - val_recall: 0.0000e+00
# Epoch 2/10
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7676 - loss: 0.5297 - recall: 0.9856 - val_accuracy: 0.2900 - val_loss: 3.3468 - val_recall: 0.0000e+00
# Epoch 3/10
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7697 - loss: 0.5264 - recall: 0.9866 - val_accuracy: 0.2898 - val_loss: 3.0930 - val_recall: 0.0000e+00
# Epoch 4/10
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7705 - loss: 0.5255 - recall: 0.9849 - val_accuracy: 0.2899 - val_loss: 3.6220 - val_recall: 0.0000e+00
# Epoch 5/10
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7720 - loss: 0.5229 - recall: 0.9853 - val_accuracy: 0.2901 - val_loss: 3.4805 - val_recall: 0.0000e+00
# Epoch 6/10
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7681 - loss: 0.5278 - recall: 0.9858 - val_accuracy: 0.2900 - val_loss: 3.7838 - val_recall: 0.0000e+00
# Epoch 7/10
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7729 - loss: 0.5235 - recall: 0.9846 - val_accuracy: 0.2902 - val_loss: 3.7375 - val_recall: 0.0000e+00
# Epoch 8/10
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7684 - loss: 0.5287 - recall: 0.9826 - val_accuracy: 0.2900 - val_loss: 3.8559 - val_recall: 0.0000e+00
# Epoch 9/10
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7696 - loss: 0.5258 - recall: 0.9853 - val_accuracy: 0.2900 - val_loss: 3.8519 - val_recall: 0.0000e+00
# Epoch 10/10
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7714 - loss: 0.5248 - recall: 0.9849 - val_accuracy: 0.2901 - val_loss: 4.0825 - val_recall: 0.0000e+00
# '# Evaluate the model with class weights\nloss_with_weights, accuracy_with_weights = model.evaluate(x_valid, y_valid)\nprint(f"Test Loss with class weights: {loss_with_weights}")\nprint(f"Test Accuracy with class weights: {accuracy_with_weights}")'

# %%
model.predict(x_train.iloc[0:30, :])
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000206D9B5A0C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# array([[0.80952656],
#        [0.6449462 ],
#        [0.8035846 ],
#        [0.8076757 ],
#        [0.76806545],
#        [0.766988  ],
#        [0.7521202 ],
#        [0.80463624],
#        [0.7710915 ],
#        [0.75428927],
#        [0.19573087],
#        [0.78938174],
#        [0.7969178 ],
#        [0.77346456],
#        [0.76208997],
#        [0.6635387 ],
#        [0.7932297 ],
#        [0.8069422 ],
#        [0.80965275],
#        [0.77301514],
#        [0.7741172 ],
#        [0.7672945 ],
#        [0.79139507],
#        [0.8071053 ],
#        [0.7870736 ],
#        [0.8004658 ],
#        [0.7834106 ],
#        [0.7122931 ],
#        [0.7783258 ],
#        [0.73994946]], dtype=float32)

# %%
y_train.head(30)
# Out:
# 65119    1
# 30768    0
# 50138    0
# 38661    1
# 73623    1
# 40890    1
# 71351    1
# 73296    0
# 30635    1
# 13386    1
# 39229    0
# 744      1
# 31880    0
# 57103    1
# 141      0
# 58112    0
# 62597    1
# 61705    1
# 37725    0
# 64605    1
# 56400    1
# 75033    1
# 54014    1
# 57083    1
# 65020    0
# 24689    0
# 23129    1
# 2370     0
# 76173    1
# 15798    1
# Name: done, dtype: int64
