# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing as StandardScaler
from sklearn.impute import KNNImputer
import seaborn as sns
from scipy.stats import zscore

# %% [markdown]
# ## Reading Data

# %%
df = pd.read_csv('HW2_train.csv')
df.head(10)
# Out:
#    distance  price  buying_equipment  intercity                   datetime  \
# 0     12832   1320                 0          0  2012-11-17 19:46:44+03:30
# 1      7230   1560                 0          0  2012-11-19 16:32:03+03:30
# 2      6974   1700                 0          0  2012-11-14 12:59:43+03:30
# 3      5535   1260                 0          0  2012-11-15 18:03:49+03:30
# 4      3229    700                 0          0  2012-11-15 22:06:07+03:30
# 5      4578   1060                 0          0  2012-11-19 09:24:52+03:30
# 6     14606   1760                 0          0  2012-11-18 15:17:33+03:30
# 7      9377   2560                 0          0  2012-11-13 16:12:21+03:30
# 8      6134   1620                 0          0  2012-11-21 16:55:24+03:30
# 9      2819    660                 0          0  2012-11-21 16:34:08+03:30
#
#   service_type  days_since_signup  in_hurry_enabled  done expert_group
# 0            A               1699                 0     0          NaN
# 1            A                336                 0     1            A
# 2            A                 14                 0     1            A
# 3            A                653                 0     1            A
# 4            A                739                 0     1            A
# 5            A                 44                 1     0            A
# 6            A                435                 1     1            A
# 7            A               1003                 0     0            A
# 8            A                  9                 0     0            A
# 9            A                121                 0     0          NaN

# %% [markdown]
# ## Understanding Data

# %%
df.describe()
# Out:
#             distance         price  buying_equipment     intercity  \
# count   76657.000000  76657.000000      76657.000000  76657.000000
# mean     5715.793926   1308.522379          0.012628      0.000678
# std      8379.122772    778.317691          0.111662      0.026036
# min         0.000000    200.000000          0.000000      0.000000
# 25%      2977.000000    960.000000          0.000000      0.000000
# 50%      4662.000000   1200.000000          0.000000      0.000000
# 75%      6621.000000   1480.000000          0.000000      0.000000
# max    796911.000000  64520.000000          1.000000      1.000000
#
#        days_since_signup  in_hurry_enabled          done
# count       76657.000000      76657.000000  76657.000000
# mean          717.850281          0.100239      0.708885
# std           545.526321          0.306384      0.454279
# min            -1.000000          0.000000      0.000000
# 25%           279.000000          0.000000      0.000000
# 50%           601.000000          0.000000      1.000000
# 75%          1115.000000          0.000000      1.000000
# max          2659.000000          3.000000      1.000000

# %%
tested = df['done'].value_counts().reset_index(name='count')
tested.columns = ['done', 'count']
tested
# Out:
#    done  count
# 0     1  54341
# 1     0  22316

# %%
done_df = df[df['done'] == 1].apply(list)
done_df.describe()
# Out:
#            distance         price  buying_equipment  intercity  \
# count  54341.000000  54341.000000      54341.000000    54341.0
# mean    4774.274323   1242.244714          0.013857        0.0
# std     2604.254385    395.530369          0.116898        0.0
# min        0.000000    360.000000          0.000000        0.0
# 25%     2907.000000    980.000000          0.000000        0.0
# 50%     4447.000000   1200.000000          0.000000        0.0
# 75%     6144.000000   1440.000000          0.000000        0.0
# max    47795.000000   8080.000000          1.000000        0.0
#
#        days_since_signup  in_hurry_enabled     done
# count       54341.000000      54341.000000  54341.0
# mean          700.617784          0.088349      1.0
# std           516.571244          0.288308      0.0
# min            -1.000000          0.000000      1.0
# 25%           285.000000          0.000000      1.0
# 50%           594.000000          0.000000      1.0
# 75%          1092.000000          0.000000      1.0
# max          2485.000000          3.000000      1.0

# %%
done_df = df[df['done'] == 0].apply(list)
done_df.describe()
# Out:
#             distance         price  buying_equipment     intercity  \
# count   22316.000000  22316.000000      22316.000000  22316.000000
# mean     8008.459132   1469.913067          0.009634      0.002330
# std     14739.476521   1289.670092          0.097683      0.048217
# min         0.000000    200.000000          0.000000      0.000000
# 25%      3206.750000    920.000000          0.000000      0.000000
# 50%      5390.500000   1240.000000          0.000000      0.000000
# 75%      8470.250000   1620.000000          0.000000      0.000000
# max    796911.000000  64520.000000          1.000000      1.000000
#
#        days_since_signup  in_hurry_enabled     done
# count       22316.000000      22316.000000  22316.0
# mean          759.812601          0.129190      0.0
# std           608.289552          0.344773      0.0
# min            -1.000000          0.000000      0.0
# 25%           259.750000          0.000000      0.0
# 50%           615.000000          0.000000      0.0
# 75%          1171.000000          0.000000      0.0
# max          2659.000000          3.000000      0.0

# %%
eq_df = df['buying_equipment'].value_counts().reset_index(name='count')
eq_df.columns = ['buying_equipment', 'count']
eq_df
# Out:
#    buying_equipment  count
# 0                 0  75689
# 1                 1    968

# %%
intercity_df = df['intercity'].value_counts().reset_index(name='count')
intercity_df.columns = ['intercity', 'count']
intercity_df
# Out:
#    intercity  count
# 0          0  76605
# 1          1     52

# %%
service_df = df['service_type'].value_counts().reset_index(name='count')
service_df.columns = ['service_type', 'count']
service_df
# Out:
#   service_type  count
# 0            A  76293
# 1            E    140
# 2            B    113
# 3            D     67
# 4            C     44

# %%
hurry_df = df['in_hurry_enabled'].value_counts().reset_index(name='count')
hurry_df.columns = ['in_hurry_enabled	', 'count']
hurry_df
# Out:
#    in_hurry_enabled\t  count
# 0                   0  69107
# 1                   1   7423
# 2                   2    120
# 3                   3      7

# %%
days_df = df[df['days_since_signup'] < 0]['days_since_signup'].value_counts().reset_index(name='count')
days_df.columns = ['days_since_signup', 'count']
days_df
# Out:
#    days_since_signup  count
# 0                 -1    334

# %%
exp_df = df['expert_group'].value_counts().reset_index(name='count')
exp_df.columns = ['expert_group', 'count']
exp_df
# Out:
#   expert_group  count
# 0            A  66882
# 1            B    749

# %% [markdown]
# ## Checking Duplicated Rows

# %%
duplicated_rows = df.duplicated()
duplicated_rows
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 76652    False
# 76653    False
# 76654    False
# 76655    False
# 76656    False
# Length: 76657, dtype: bool

# %% [markdown]
# #### there is no duplicated rows.

# %% [markdown]
# ## Null Values

# %%
missingValues = df.isnull().sum()
missingValues
# Out:
# distance                0
# price                   0
# buying_equipment        0
# intercity               0
# datetime                0
# service_type            0
# days_since_signup       0
# in_hurry_enabled        0
# done                    0
# expert_group         9026
# dtype: int64

# %% [markdown]
# #### only expert_group column has null values.

# %%
#fix_null = df
#one_hot = pd.get_dummies(df['service_type'])
#fix_null = fix_null.drop('service_type',axis = 1)
#fix_null = fix_null.join(one_hot)
#fix_null

# %% [markdown]
# ## Filling The Null Values

# %%
fill_df = df[["in_hurry_enabled", "service_type", "expert_group"]]
fill_df = pd.get_dummies(fill_df, columns=['service_type'])

non_null_df = fill_df[fill_df["expert_group"].notna()]
null_df = fill_df[fill_df["expert_group"].isna()]

x_non_null = non_null_df.drop(columns = ["expert_group"])
y_non_null = non_null_df["expert_group"].astype("category").cat.codes

categories = non_null_df["expert_group"].astype("category").cat.categories

x_null = null_df.drop(columns = ["expert_group"])

y_non_null = y_non_null.astype("category").cat.categories

imputer = KNNImputer(n_neighbors = 2)
imputer.fit(x_non_null)

x_null_imputed = imputer.transform(x_null)

null_df = null_df.copy()

null_df["expert_group"] = pd.Categorical.from_codes(
    x_null_imputed[:, -1].round().astype(int), categories
)

#null_df.loc[:, "expert_group"] = x_null_imputed[:, -1]

final_df = pd.concat([non_null_df, null_df])

final_df
# Out:
#        in_hurry_enabled expert_group  service_type_A  service_type_B  \
# 1                     0            A            True           False
# 2                     0            A            True           False
# 3                     0            A            True           False
# 4                     0            A            True           False
# 5                     1            A            True           False
# ...                 ...          ...             ...             ...
# 76593                 0            A            True           False
# 76605                 1            A            True           False
# 76624                 0            A            True           False
# 76635                 0            A            True           False
# 76638                 1            A            True           False
#
#        service_type_C  service_type_D  service_type_E
# 1               False           False           False
# 2               False           False           False
# 3               False           False           False
# 4               False           False           False
# 5               False           False           False
# ...               ...             ...             ...
# 76593           False           False           False
# 76605           False           False           False
# 76624           False           False           False
# 76635           False           False           False
# 76638           False           False           False
#
# [76657 rows x 7 columns]

# %% [markdown]
# ### Merging Two Tables

# %%
df.drop(columns = "service_type", inplace = True)
df.drop(columns = "expert_group", inplace = True)
df
# Out:
#        distance  price  buying_equipment  intercity  \
# 0         12832   1320                 0          0
# 1          7230   1560                 0          0
# 2          6974   1700                 0          0
# 3          5535   1260                 0          0
# 4          3229    700                 0          0
# ...         ...    ...               ...        ...
# 76652      6199   1560                 0          0
# 76653      8667   2040                 0          0
# 76654      1003    620                 0          0
# 76655      1995    960                 0          0
# 76656      3847    700                 0          0
#
#                         datetime  days_since_signup  in_hurry_enabled  done
# 0      2012-11-17 19:46:44+03:30               1699                 0     0
# 1      2012-11-19 16:32:03+03:30                336                 0     1
# 2      2012-11-14 12:59:43+03:30                 14                 0     1
# 3      2012-11-15 18:03:49+03:30                653                 0     1
# 4      2012-11-15 22:06:07+03:30                739                 0     1
# ...                          ...                ...               ...   ...
# 76652  2012-11-19 12:14:17+03:30                104                 0     1
# 76653  2012-11-20 20:52:53+03:30               1311                 0     0
# 76654  2012-11-13 15:37:52+03:30                847                 0     1
# 76655  2012-11-18 18:04:58+03:30                401                 1     1
# 76656  2012-11-17 09:27:39+03:30                 69                 0     1
#
# [76657 rows x 8 columns]

# %%
df = df.merge(final_df, left_index = True, right_index = True)

# %%
df
# Out:
#        distance  price  buying_equipment  intercity  \
# 0         12832   1320                 0          0
# 1          7230   1560                 0          0
# 2          6974   1700                 0          0
# 3          5535   1260                 0          0
# 4          3229    700                 0          0
# ...         ...    ...               ...        ...
# 76652      6199   1560                 0          0
# 76653      8667   2040                 0          0
# 76654      1003    620                 0          0
# 76655      1995    960                 0          0
# 76656      3847    700                 0          0
#
#                         datetime  days_since_signup  in_hurry_enabled_x  done  \
# 0      2012-11-17 19:46:44+03:30               1699                   0     0
# 1      2012-11-19 16:32:03+03:30                336                   0     1
# 2      2012-11-14 12:59:43+03:30                 14                   0     1
# 3      2012-11-15 18:03:49+03:30                653                   0     1
# 4      2012-11-15 22:06:07+03:30                739                   0     1
# ...                          ...                ...                 ...   ...
# 76652  2012-11-19 12:14:17+03:30                104                   0     1
# 76653  2012-11-20 20:52:53+03:30               1311                   0     0
# 76654  2012-11-13 15:37:52+03:30                847                   0     1
# 76655  2012-11-18 18:04:58+03:30                401                   1     1
# 76656  2012-11-17 09:27:39+03:30                 69                   0     1
#
#        in_hurry_enabled_y expert_group  service_type_A  service_type_B  \
# 0                       0            A            True           False
# 1                       0            A            True           False
# 2                       0            A            True           False
# 3                       0            A            True           False
# 4                       0            A            True           False
# ...                   ...          ...             ...             ...
# 76652                   0            A            True           False
# 76653                   0            A            True           False
# 76654                   0            A            True           False
# 76655                   1            A            True           False
# 76656                   0            A            True           False
#
#        service_type_C  service_type_D  service_type_E
# 0               False           False           False
# 1               False           False           False
# 2               False           False           False
# 3               False           False           False
# 4               False           False           False
# ...               ...             ...             ...
# 76652           False           False           False
# 76653           False           False           False
# 76654           False           False           False
# 76655           False           False           False
# 76656           False           False           False
#
# [76657 rows x 15 columns]

# %%
df = pd.get_dummies(df, columns=['expert_group'])

# %%
df
# Out:
#        distance  price  buying_equipment  intercity  \
# 0         12832   1320                 0          0
# 1          7230   1560                 0          0
# 2          6974   1700                 0          0
# 3          5535   1260                 0          0
# 4          3229    700                 0          0
# ...         ...    ...               ...        ...
# 76652      6199   1560                 0          0
# 76653      8667   2040                 0          0
# 76654      1003    620                 0          0
# 76655      1995    960                 0          0
# 76656      3847    700                 0          0
#
#                         datetime  days_since_signup  in_hurry_enabled_x  done  \
# 0      2012-11-17 19:46:44+03:30               1699                   0     0
# 1      2012-11-19 16:32:03+03:30                336                   0     1
# 2      2012-11-14 12:59:43+03:30                 14                   0     1
# 3      2012-11-15 18:03:49+03:30                653                   0     1
# 4      2012-11-15 22:06:07+03:30                739                   0     1
# ...                          ...                ...                 ...   ...
# 76652  2012-11-19 12:14:17+03:30                104                   0     1
# 76653  2012-11-20 20:52:53+03:30               1311                   0     0
# 76654  2012-11-13 15:37:52+03:30                847                   0     1
# 76655  2012-11-18 18:04:58+03:30                401                   1     1
# 76656  2012-11-17 09:27:39+03:30                 69                   0     1
#
#        in_hurry_enabled_y  service_type_A  service_type_B  service_type_C  \
# 0                       0            True           False           False
# 1                       0            True           False           False
# 2                       0            True           False           False
# 3                       0            True           False           False
# 4                       0            True           False           False
# ...                   ...             ...             ...             ...
# 76652                   0            True           False           False
# 76653                   0            True           False           False
# 76654                   0            True           False           False
# 76655                   1            True           False           False
# 76656                   0            True           False           False
#
#        service_type_D  service_type_E  expert_group_A  expert_group_B
# 0               False           False            True           False
# 1               False           False            True           False
# 2               False           False            True           False
# 3               False           False            True           False
# 4               False           False            True           False
# ...               ...             ...             ...             ...
# 76652           False           False            True           False
# 76653           False           False            True           False
# 76654           False           False            True           False
# 76655           False           False            True           False
# 76656           False           False            True           False
#
# [76657 rows x 16 columns]

# %% [markdown]
# ## Outlier Detection

# %% [markdown]
# #### The feature that might contain outliers are "distance", "price", and "days_since_signup".

# %% [markdown]
# ### Distance Outliers

# %%
sns.boxplot(x=df['distance'])
# Out:
# <Axes: xlabel='distance'>

# %%
sns.histplot(df['distance'])
# Out:
# <Axes: xlabel='distance', ylabel='Count'>

# %%
df['z_score'] = zscore(df['distance'])

# %%
for threshold in [2, 2.5, 3, 3.5, 4, 4.5]:
    outliers = df['z_score'].abs() > threshold
    num_outliers = outliers.sum()
    print(f'Threshold: {threshold}, Outliers Detected: {num_outliers}')
# Out:
# Threshold: 2, Outliers Detected: 1014
# Threshold: 2.5, Outliers Detected: 739
# Threshold: 3, Outliers Detected: 568
# Threshold: 3.5, Outliers Detected: 465
# Threshold: 4, Outliers Detected: 387
# Threshold: 4.5, Outliers Detected: 329

# %% [markdown]
# #### Based on the result we will set the threshold to 3.

# %%
threshold = 3
df['is_outlier'] = df['z_score'].abs() > threshold

# %%
sorted_df = df.sort_values(by = 'distance')
sorted_df
# Out:
#        distance  price  buying_equipment  intercity  \
# 5722        0.0   1080                 0          0
# 46192       0.0    720                 0          0
# 53738       0.0    480                 0          0
# 67556       0.0    540                 0          0
# 21929       0.0    600                 0          0
# ...         ...    ...               ...        ...
# 27827   30716.0   2500                 0          0
# 15286   30725.0   2500                 0          0
# 63431   30821.0   2020                 0          0
# 12936   30841.0   1440                 0          0
# 75002   30852.0   2260                 0          0
#
#                         datetime  days_since_signup  in_hurry_enabled_x  done  \
# 5722   2012-11-21 12:56:11+03:30                 54                   0     0
# 46192  2012-11-21 17:59:57+03:30                519                   0     0
# 53738  2012-11-19 20:00:26+03:30                478                   0     0
# 67556  2012-11-17 06:46:42+03:30                394                   0     0
# 21929  2012-11-21 19:22:48+03:30                242                   0     0
# ...                          ...                ...                 ...   ...
# 27827  2012-11-14 23:48:18+03:30                766                   0     0
# 15286  2012-11-13 09:45:43+03:30                229                   0     0
# 63431  2012-11-12 13:06:35+03:30                508                   0     0
# 12936  2012-11-16 16:37:27+03:30               1899                   0     0
# 75002  2012-11-13 11:58:25+03:30                547                   0     0
#
#        in_hurry_enabled_y  service_type_A  service_type_B  service_type_C  \
# 5722                    0           False            True           False
# 46192                   0            True           False           False
# 53738                   0            True           False           False
# 67556                   0            True           False           False
# 21929                   0            True           False           False
# ...                   ...             ...             ...             ...
# 27827                   0            True           False           False
# 15286                   0            True           False           False
# 63431                   0            True           False           False
# 12936                   0            True           False           False
# 75002                   0            True           False           False
#
#        service_type_D  service_type_E  expert_group_A  expert_group_B  \
# 5722            False           False            True           False
# 46192           False           False           False            True
# 53738           False           False            True           False
# 67556           False           False            True           False
# 21929           False           False            True           False
# ...               ...             ...             ...             ...
# 27827           False           False            True           False
# 15286           False           False            True           False
# 63431           False           False            True           False
# 12936           False           False            True           False
# 75002           False           False            True           False
#
#         z_score  is_outlier
# 5722  -0.293613       False
# 46192 -0.756152       False
# 53738 -1.064511       False
# 67556 -0.987421       False
# 21929 -0.910331       False
# ...         ...         ...
# 27827  1.530847       False
# 15286  1.530847       False
# 63431  0.914128       False
# 12936  0.168926       False
# 75002  1.222488       False
#
# [76657 rows x 18 columns]

# %%
cap_value = df['distance'].quantile(0.95)
df['distance'] = np.where(df['is_outlier'], cap_value, df['distance'])

# %%
check_df = df[df['is_outlier'] == True]
check_df
# Out:
#        distance   price  buying_equipment  intercity  \
# 60      12081.0  2200.0                 1          0
# 185     12081.0  2200.0                 0          1
# 459     12081.0  2200.0                 0          0
# 613     12081.0  2200.0                 0          0
# 947     12081.0  2200.0                 0          0
# ...         ...     ...               ...        ...
# 76151   12081.0  2200.0                 0          0
# 76294   12081.0  2200.0                 0          0
# 76365   12081.0  2200.0                 0          0
# 76501   12081.0  2200.0                 1          0
# 76545   12081.0  2200.0                 0          1
#
#                         datetime  days_since_signup  in_hurry_enabled_x  done  \
# 60     2012-11-19 13:46:24+03:30                869                   0     0
# 185    2012-11-17 11:54:07+03:30               1933                   0     0
# 459    2012-11-13 18:42:08+03:30                792                   0     0
# 613    2012-11-17 16:53:27+03:30               1439                   1     0
# 947    2012-11-21 13:19:04+03:30               2118                   1     0
# ...                          ...                ...                 ...   ...
# 76151  2012-11-19 07:34:39+03:30                 57                   0     0
# 76294  2012-11-18 22:06:25+03:30                856                   1     0
# 76365  2012-11-14 17:09:49+03:30               1906                   0     0
# 76501  2012-11-16 22:53:00+03:30                301                   0     1
# 76545  2012-11-18 09:31:30+03:30                839                   0     0
#
#        in_hurry_enabled_y  service_type_A  service_type_B  service_type_C  \
# 60                      0           False           False           False
# 185                     0            True           False           False
# 459                     0            True           False           False
# 613                     1            True           False           False
# 947                     1            True           False           False
# ...                   ...             ...             ...             ...
# 76151                   0            True           False           False
# 76294                   1            True           False           False
# 76365                   0            True           False           False
# 76501                   0            True           False           False
# 76545                   0            True           False           False
#
#        service_type_D  service_type_E  expert_group_A  expert_group_B  \
# 60              False            True           False            True
# 185             False           False            True           False
# 459             False           False            True           False
# 613             False           False            True           False
# 947             False           False            True           False
# ...               ...             ...             ...             ...
# 76151           False           False            True           False
# 76294           False           False            True           False
# 76365           False           False            True           False
# 76501           False           False            True           False
# 76545           False           False            True           False
#
#          z_score  is_outlier
# 60      6.104845        True
# 185    25.557183        True
# 459     7.389675        True
# 613     5.179767        True
# 947     3.689363        True
# ...          ...         ...
# 76151   4.203295        True
# 76294   3.124037        True
# 76365   5.231160        True
# 76501   3.612273        True
# 76545  67.545452        True
#
# [843 rows x 18 columns]

# %% [markdown]
# #### Invalid Distances (Negative Distances):

# %%
positive_mean = df[df['distance'] > 0]['distance'].mean()

# %%
df['distance'] = df['distance'].apply(lambda x: positive_mean if x < 0 else x)

# %%
sns.histplot(df['distance'])
# Out:
# <Axes: xlabel='distance', ylabel='Count'>

# %% [markdown]
# ### Price Outliers

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
df['z_score'] = zscore(df['price'])

# %%
for threshold in [2, 2.5, 3, 3.5, 4, 4.5]:
    outliers = df['z_score'].abs() > threshold
    num_outliers = outliers.sum()
    print(f'Threshold: {threshold}, Outliers Detected: {num_outliers}')
# Out:
# Threshold: 2, Outliers Detected: 1726
# Threshold: 2.5, Outliers Detected: 1209
# Threshold: 3, Outliers Detected: 843
# Threshold: 3.5, Outliers Detected: 629
# Threshold: 4, Outliers Detected: 461
# Threshold: 4.5, Outliers Detected: 349

# %%
threshold = 3
df['is_outlier'] = df['z_score'].abs() > threshold

# %%
cap_value = df['price'].quantile(0.95)
df['price'] = np.where(df['is_outlier'], cap_value, df['price'])

# %%
sns.histplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# ### Days Since Signup Outlier

# %%
sns.boxplot(x=df['days_since_signup'])
# Out:
# <Axes: xlabel='days_since_signup'>

# %%
df['z_score'] = zscore(df['days_since_signup'])

# %%
for threshold in [2, 2.5, 3, 3.5, 4, 4.5]:
    outliers = df['z_score'].abs() > threshold
    num_outliers = outliers.sum()
    print(f'Threshold: {threshold}, Outliers Detected: {num_outliers}')
# Out:
# Threshold: 2, Outliers Detected: 3822
# Threshold: 2.5, Outliers Detected: 1133
# Threshold: 3, Outliers Detected: 95
# Threshold: 3.5, Outliers Detected: 1
# Threshold: 4, Outliers Detected: 0
# Threshold: 4.5, Outliers Detected: 0
